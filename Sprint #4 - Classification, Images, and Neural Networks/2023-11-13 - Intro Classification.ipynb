# %%
# %matplotlib inline
from pylab import *

# %%
from classy import *
# Out:
# Version:  0.0.35

# %%
data=load_excel('data/iris.xls')
# Out:
# iris.data 151 5
# 150 vectors of length 4
# Feature names: 'petal length in cm', 'petal width in cm', 'sepal length in cm', 'sepal width in cm'
# Target values given.
# Target names: 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'
# Mean:  [3.75866667 1.19866667 5.84333333 3.054     ]
# Median:  [4.35 1.3  5.8  3.  ]
# Stddev:  [1.75852918 0.76061262 0.82530129 0.43214658]

# %%
plot2D(data)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot2D(data)
#
# File ~/anaconda3/lib/python3.11/site-packages/classy/utils.py:180, in plot2D(data, classifier, axis_range, number_of_grid_points, legend_location)
#     174 from matplotlib.lines import Line2D
#     176 from matplotlib.colors import ListedColormap
# --> 180 assert len(data.feature_names)==2,"Function only works for 2D data."
#     181 assert len(data.target_names)<=len(bold_colors),"Only %d target colors implemented." % (len(cmap_bold.colors))
#     184 cmap_light = ListedColormap(light_colors[:len(data.target_names)])
#
# AssertionError: Function only works for 2D data.

# %%
subset=extract_features(data,[0,2])

# %%
plot2D(subset)
